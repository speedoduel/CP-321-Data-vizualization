# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import pandas as pd
import matplotlib.pyplot as plt
d = {'Movie': ["Star Wars: The Last Jedi", 
             "Jumanji: Welcome to the Jungle",
             "Pitch Perfect 3",
             "The Greatest Showman",
             "Ferdinand"], 
     'Weekend Gross': [71565498, 36169328,19928525,8805843,7316746],
     'Weekday Gross': [51565498, 26169328,9928525,805843,7016746]
    }

df = pd.DataFrame(data=d)

# Setting the positions and width for the bars
pos = list(range(len(df['Movie']))) 
width = 0.4
    
# Plotting the bars
fig, ax = plt.subplots(figsize=(15,5))

# Create a bar with Weekend Gross data,
# in position pos,
plt.bar(pos, 
        df['Weekend Gross']/1000000, 
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#EE3224', 
        # with label the first value in first_name
        label=df['Weekend Gross'][0]) 

# Create a bar with Weekday Gross data,
# in position pos + some width buffer,
plt.bar([p + width for p in pos], 
        df['Weekday Gross']/1000000,
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#F78F1E', 
        # with label the second value in first_name
        label=df['Weekday Gross'][1]) 

# Set the y axis label
ax.set_ylabel('Gross in Million',fontsize=16)

# Set the position of the x ticks
ax.set_xticks([p + 0.5 * width for p in pos])

# Set the labels for the x ticks
ax.set_xticklabels(df['Movie'])

# Adding the legend and showing the plot
plt.legend(['Weekend Gross', 'Weekday Gross'], loc='upper right',fontsize=16)
#plt.grid()
plt.show()

# %% [markdown]
# Example from: https://chrisalbon.com/python/data_visualization/matplotlib_grouped_bar_plot/

# %%
fig, ax = plt.subplots(figsize=(8,5))

# Create a bar with Weekend Gross data,
# in position pos,
plt.barh(pos, 
        df['Weekend Gross']/1000000, 
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#EE3224', 
        # with label the first value in first_name
        label=df['Weekend Gross'][0]) 

# Create a bar with Weekday Gross data,
# in position pos + some width buffer,
plt.barh([p + width for p in pos], 
        df['Weekday Gross']/1000000,
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#F78F1E', 
        # with label the second value in first_name
        label=df['Weekday Gross'][1]) 

# Set the x axis label
ax.set_xlabel('Gross in Million',fontsize=12)

# Set the position of the y ticks
ax.set_yticks([p + 0.5 * width for p in pos])

# Set the labels for the y ticks
ax.set_yticklabels(df['Movie'])

# Adding the legend and showing the plot
plt.legend(['Weekend Gross', 'Weekday Gross'], loc='upper right',fontsize=12)
#plt.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(13,5))

# Create a bar with Weekend Gross data,
p1 = plt.bar(pos, 
        df['Weekend Gross']/1000000, 
        width = 0.5,
        label=df['Weekend Gross'][0]) 

# Create a bar with Weekday Gross data,
p2 = plt.bar(pos, 
        df['Weekday Gross']/1000000,
        width = 0.5,
        label=df['Weekday Gross'][1],
        bottom=df['Weekend Gross']/1000000) 

plt.legend(('Weekend Gross','Weekday Gross'), loc='upper right',fontsize=16)

# Set the y axis label
ax.set_ylabel('Gross in Million',fontsize=16)

# Set the position of the x ticks
ax.set_xticks(pos)

# Set the labels for the x ticks
ax.set_xticklabels(df['Movie'])
plt.show()
